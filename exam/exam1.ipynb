# %%
import pandas as pd
import numpy as np
paris_df =pd.read_csv('C:/Users/devdi/Desktop/DSCourseIPD20221/exam/listings.csv')
paris_df.head()
# Out:
# C:\Users\devdi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (43,61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      id                        listing_url       scrape_id last_scraped  \
# 0  2577  https://www.airbnb.com/rooms/2577  20181207151406   2018-12-08
# 1  3109  https://www.airbnb.com/rooms/3109  20181207151406   2018-12-08
# 2  5396  https://www.airbnb.com/rooms/5396  20181207151406   2018-12-08
# 3  7397  https://www.airbnb.com/rooms/7397  20181207151406   2018-12-08
# 4  7964  https://www.airbnb.com/rooms/7964  20181207151406   2018-12-08
#
#                                 name  \
# 0   Loft for 4 by Canal Saint Martin
# 1                       zen and calm
# 2     Explore the heart of old Paris
# 3   MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 4  Large & sunny flat with balcony !
#
# ...

# %%
#Le nombres delignes et de colonnes (59881 lignes et 96 colonnes)
paris_df.shape
# Out:
# (59881, 96)

# %%
#Afficher le nom des differentes colonnes
paris_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
# ...

# %%
#Cet ensemble de donnes ne contient que les annonces de Paris
#Conserver uniquement des annonces de is_location_exact
df_exact_location=paris_df['is_location_exact']=='Paris'
print(df_exact_location)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 59876    False
# 59877    False
# 59878    False
# 59879    False
# 59880    False
# Name: is_location_exact, Length: 59881, dtype: bool

# %% [markdown]
# #### Qu'est ce qu'une donnees aberrantes?
# Une donnee est aberrante quand elle n'est pas en accord avec les esultats attendus et n'est pas dans le meme ensemble devaleur que les autres donnees

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#Visualisez les annonces classées dans la catégorie "Maison entière / appartement" sur une carte.
data= pd.read_csv('C:/Users/hp/Documents/Cours ipd/tp3/src/input/listings.csv',encoding='utf-8')
sns.scatterplot(data=data, x="calculated_host_listings_count_entire_homes", y="calculated_host_listings_count_private_rooms")
plt.show()

# %%
#Visualisez cette même carte avec des couleurs variables en fonction du prix
sns.scatterplot(data=data, x="calculated_host_listings_count_entire_homes", y="calculated_host_listings_count_private_rooms",hue="price")

plt.show()

# %%
#Visualisez cette même carte avec des couleurs variables en fonction du prix
#plt.rcParams['font.sans-serif'] = ['Source Han Sans TW', 'sans-serif']
sns.scatterplot(data=data, x="calculated_host_listings_count_entire_homes", y="calculated_host_listings_count_private_rooms",hue="neighbourhood")

plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hp\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 24052 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hp\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 40654 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hp\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 27861 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hp\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20848 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
